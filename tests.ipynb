# %%
import io
import os
import glob
import pickle
from PIL import Image
import numpy as np
import matplotlib 
#matplotlib.use("TKAgg")
#matplotlib.use("WXAgg")
import matplotlib.pyplot as plt
from scipy import signal
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from sklearn.linear_model import LogisticRegression
import torch
import torchvision.transforms.functional as TF
from tqdm import tqdm

#DINOV3_GITHUB_LOCATION = "facebookresearch/dinov3"
#DINOV3_LOCATION = "/home/levandov/dinov3/dinov3"
#DINOV3_GITHUB_LOCATION = "levandov/dinov3"
#DINOV3_LOCATION

#if os.getenv("DINOV3_LOCATION") is not None:
#    DINOV3_LOCATION = os.getenv("DINOV3_LOCATION")
#else:
#    
#DINOV3_LOCATION = DINOV3_GITHUB_LOCATION

#print(f"DINOv3 location set to {DINOV3_LOCATION}")

# examples of available DINOv3 models:
#MODEL_DINOV3_VITS = "dinov3_vits16"
#MODEL_DINOV3_VITSP = "dinov3_vits16plus"
#MODEL_DINOV3_VITB = "dinov3_vitb16"
MODEL_DINOV3_VITL = "dinov3_vitl16"
#MODEL_DINOV3_VITHP = "dinov3_vith16plus"
#MODEL_DINOV3_VIT7B = "dinov3_vit7b16"

MODEL_NAME = MODEL_DINOV3_VITL

import torch

REPO_DIR = "/home/levandov/dinov3/dinov3"
#"home/levandov/.cache/torch/hub/checkpoints"

#DINOv3 ViT SAT-493M
#dinov3_vitl16_pretrain_sat493m-eadcf0ff.pth sits among links from META
## are these weights for dinov3_vitl16 ?

#indian guy install: 
#"filename": "dinov3_vitl16_pretrain_sat493m-eadcf0ff.pth",
# "url": "..............................",
# "description": "DINOv3 ViT-L/16 SAT-493M"


# DINOv3 ViT models pretrained on web images
#dinov3_vitl16 = torch.hub.load(REPO_DIR, 'dinov3_vitl16', source='local', weights=<CHECKPOINT/URL/OR/PATH>)
# DINOv3 ViT models pretrained on satellite imagery
#dinov3_vitl16 = 
#model = torch.hub.load(REPO_DIR, 'dinov3_vitl16', source='local',) 
#weights=<CHECKPOINT/URL/OR/PATH>

#model = torch.hub.load(
#    repo_or_dir=DINOV3_LOCATION,
#    model=MODEL_NAME,
#    source="local" if DINOV3_LOCATION != DINOV3_GITHUB_LOCATION else "github",
#)
#model.cuda()

#

DPATH = "/home/levandov/dv"
train_images_dir = DPATH + "/images/"
train_labels_dir = DPATH + "/labels/"

#images = []
#images = sorted(os.listdir(train_images_dir))
#print(images[2])
#train_images_dir+"*.png")

images = []
for member in sorted(glob.glob(train_images_dir+"*.png")):
#  print(member)
  image = Image.open(member)
#  plt.figure(figsize=(4, 4), dpi=75)
#  plt.axis('off')
#  plt.show()
  images.append(image)
print("images: "+str(len(images)))
labels = []
for member in sorted(glob.glob(train_labels_dir+"*.png")):
  label = Image.open(member)
#  plt.show()
  labels.append(label)
print("labels: "+str(len(labels)))

n_images = len(images)
assert n_images == len(labels), f"{len(images)=}, {len(labels)=}"

print(f"Loaded {n_images} images and labels")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 11
#       8 #matplotlib.use("TKAgg")
#       9 #matplotlib.use("WXAgg")
#      10 import matplotlib.pyplot as plt
# ---> 11 from scipy import signal
#      12 from sklearn.metrics import precision_recall_curve
#      13 from sklearn.metrics import average_precision_score
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File /usr/local/lib/python3.10/dist-packages/scipy/__init__.py:134, in __getattr__(name)
#     132 def __getattr__(name):
#     133     if name in submodules:
# --> 134         return _importlib.import_module(f'scipy.{name}')
#     135     else:
#     136         try:
#
# File /usr/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File /usr/local/lib/python3.10/dist-packages/scipy/signal/__init__.py:293
#       1 """
#       2 =======================================
#       3 Signal processing (:mod:`scipy.signal`)
#    (...)
#     290
#     291 """
# --> 293 from . import _sigtools, windows
#     294 from ._waveforms import *
#     295 from ._max_len_seq import max_len_seq
#
# File /usr/local/lib/python3.10/dist-packages/scipy/signal/windows/__init__.py:42
#       1 """
#       2 Window functions (:mod:`scipy.signal.windows`)
#       3 ==============================================
#    (...)
#      39
#      40 """
# ---> 42 from ._windows import *
#      44 # Deprecated namespaces, to be removed in v2.0.0
#      45 from . import windows
#
# File /usr/local/lib/python3.10/dist-packages/scipy/signal/windows/_windows.py:7
#       4 import warnings
#       6 import numpy as np
# ----> 7 from scipy import linalg, special, fft as sp_fft
#       9 __all__ = ['boxcar', 'triang', 'parzen', 'bohman', 'blackman', 'nuttall',
#      10            'blackmanharris', 'flattop', 'bartlett', 'barthann',
#      11            'hamming', 'kaiser', 'kaiser_bessel_derived', 'gaussian',
#      12            'general_cosine', 'general_gaussian', 'general_hamming',
#      13            'chebwin', 'cosine', 'hann', 'exponential', 'tukey', 'taylor',
#      14            'dpss', 'get_window', 'lanczos']
#      17 def _len_guards(M):
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File /usr/local/lib/python3.10/dist-packages/scipy/__init__.py:134, in __getattr__(name)
#     132 def __getattr__(name):
#     133     if name in submodules:
# --> 134         return _importlib.import_module(f'scipy.{name}')
#     135     else:
#     136         try:
#
# File /usr/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File /usr/local/lib/python3.10/dist-packages/scipy/linalg/__init__.py:205
#     203 from ._misc import *
#     204 from ._cythonized_array_utils import *
# --> 205 from ._basic import *
#     206 from ._decomp import *
#     207 from ._decomp_lu import *
#
# File /usr/local/lib/python3.10/dist-packages/scipy/linalg/_basic.py:14
#      12 from .lapack import get_lapack_funcs, _compute_lwork
#      13 from ._misc import LinAlgError, _datacopied, LinAlgWarning
# ---> 14 from ._decomp import _asarray_validated
#      15 from . import _decomp, _decomp_svd
#      16 from ._solve_toeplitz import levinson
#
# File /usr/local/lib/python3.10/dist-packages/scipy/linalg/_decomp.py:24
#      20 from numpy import (array, isfinite, inexact, nonzero, iscomplexobj,
#      21                    flatnonzero, conj, asarray, argsort, empty,
#      22                    iscomplex, zeros, einsum, eye, inf)
#      23 # Local imports
# ---> 24 from scipy._lib._util import _asarray_validated
#      25 from ._misc import LinAlgError, _datacopied, norm
#      26 from .lapack import get_lapack_funcs, _compute_lwork
#
# File /usr/local/lib/python3.10/dist-packages/scipy/_lib/_util.py:13
#      10 from typing import TypeAlias, TypeVar
#      12 import numpy as np
# ---> 13 from scipy._lib._array_api import array_namespace, is_numpy, xp_size
#      14 from scipy._lib._docscrape import FunctionDoc, Parameter
#      17 AxisError: type[Exception]
#
# File /usr/local/lib/python3.10/dist-packages/scipy/_lib/_array_api.py:18
#      15 import numpy.typing as npt
#      17 from scipy._lib import array_api_compat
# ---> 18 from scipy._lib.array_api_compat import (
#      19     is_array_api_obj,
#      20     size as xp_size,
#      21     numpy as np_compat,
#      22     device as xp_device,
#      23     is_numpy_namespace as is_numpy,
#      24     is_cupy_namespace as is_cupy,
#      25     is_torch_namespace as is_torch,
#      26     is_jax_namespace as is_jax,
#      27     is_array_api_strict_namespace as is_array_api_strict
#      28 )
#      30 __all__ = [
#      31     '_asarray', 'array_namespace', 'assert_almost_equal', 'assert_array_almost_equal',
#      32     'get_xp_devices',
#    (...)
#      38     'xp_take_along_axis', 'xp_unsupported_param_msg', 'xp_vector_norm',
#      39 ]
#      42 # To enable array API and strict array-like input validation
#
# File /usr/local/lib/python3.10/dist-packages/scipy/_lib/array_api_compat/numpy/__init__.py:1
# ----> 1 from numpy import * # noqa: F403
#       3 # from numpy import * doesn't overwrite these builtin names
#       4 from numpy import abs, max, min, round # noqa: F401
#
# File <frozen importlib._bootstrap>:1073, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/.local/lib/python3.10/site-packages/numpy/__init__.py:361, in __getattr__(attr)
#     359     return matlib
#     360 elif attr == "f2py":
# --> 361     import numpy.f2py as f2py
#     362     return f2py
#     363 elif attr == "typing":
#
# File ~/.local/lib/python3.10/site-packages/numpy/f2py/__init__.py:18
#      15 import warnings
#      17 from numpy.exceptions import VisibleDeprecationWarning
# ---> 18 from . import f2py2e
#      19 from . import diagnose
#      21 run_main = f2py2e.run_main
#
# File ~/.local/lib/python3.10/site-packages/numpy/f2py/f2py2e.py:20
#      17 import argparse
#      19 from . import crackfortran
# ---> 20 from . import rules
#      21 from . import cb_rules
#      22 from . import auxfuncs
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:879, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1012, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:672, in _compile_bytecode(data, name, bytecode_path, source_path)
#
# KeyboardInterrupt:

# %%
#Building Per-Patch Label Map
PATCH_SIZE = 16
IMAGE_SIZE = 768
patch_quant_filter = torch.nn.Conv2d(1, 1, PATCH_SIZE, stride=PATCH_SIZE, bias=False)
patch_quant_filter.weight.data.fill_(1.0 / (PATCH_SIZE * PATCH_SIZE))

# image resize transform to dimensions divisible by patch size
def resize_transform(
    mask_image: Image,
    image_size: int = IMAGE_SIZE,
    patch_size: int = PATCH_SIZE,
) -> torch.Tensor:
    w, h = mask_image.size
    h_patches = int(image_size / patch_size)
    w_patches = int((w * image_size) / (h * patch_size))
    return TF.to_tensor(TF.resize(mask_image, (h_patches * patch_size, w_patches * patch_size)))

mask_0 = labels[0].split()[-1]
mask_0_resized = resize_transform(mask_0)
with torch.no_grad():
    mask_0_quantized = patch_quant_filter(mask_0_resized).squeeze().detach().cpu()

plt.figure(figsize=(4, 2), dpi=300)
plt.subplot(1, 2, 1)
plt.imshow(mask_0,cmap='gray')
plt.axis('off')
#plt.savefig('mask0.png', bbox_inches='tight')
plt.title(f"Original Mask, Size {mask_0.size}", fontsize=5)
plt.subplot(1, 2, 2)
plt.imshow(mask_0_quantized,cmap='gray')
plt.axis('off')
plt.title(f"Quantized Mask, Size {tuple(mask_0_quantized.shape)}", fontsize=5)
#plt.savefig('mask0_q.png', bbox_inches='tight')
#saves both pics with format
plt.show()

# %%
xs = []
ys = []
image_index = []

IMAGENET_MEAN = (0.485, 0.456, 0.406)
IMAGENET_STD = (0.229, 0.224, 0.225)
#MODEL_TO_NUM_LAYERS[MODEL_NAME]
n_layers = 24

with torch.inference_mode():
    with torch.autocast(device_type='cuda', dtype=torch.float32):
        for i in tqdm(range(n_images), desc="Processing images"):
            # Loading the ground truth
            mask_i = labels[i].split()[-1]
            mask_i_resized = resize_transform(mask_i)
            mask_i_quantized = patch_quant_filter(mask_i_resized).squeeze().view(-1).detach().cpu()
            ys.append(mask_i_quantized)
            # Loading the image data 
            image_i = images[i].convert('RGB')
            image_i_resized = resize_transform(image_i)
            image_i_resized = TF.normalize(image_i_resized, mean=IMAGENET_MEAN, std=IMAGENET_STD)
            image_i_resized = image_i_resized.unsqueeze(0).cuda()

            feats = model.get_intermediate_layers(image_i_resized, n=range(n_layers), reshape=True, norm=True)
            dim = feats[-1].shape[1]
            xs.append(feats[-1].squeeze().view(dim, -1).permute(1,0).detach().cpu())

            image_index.append(i * torch.ones(ys[-1].shape))

# Concatenate all lists into torch tensors 
xs = torch.cat(xs)
ys = torch.cat(ys)
image_index = torch.cat(image_index)

# keeping only the patches that have clear positive or negative label
idx = (ys < 0.01) | (ys > 0.99)
xs = xs[idx]
ys = ys[idx]
image_index = image_index[idx]

print("Design matrix of size : ", xs.shape)
print("Label matrix of size : ", ys.shape)
# Out:
# Processing images: 100%|███████████████████████████████████████████████████████████████████████████| 24/24 [04:06<00:00, 10.27s/it]
# Design matrix of size :  torch.Size([50648, 1024])
# Label matrix of size :  torch.Size([50648])

# %%
cs = np.logspace(-7, 0, 23)
scores = np.zeros((n_images, len(cs)))

# %%
for i in range(n_images):
    # We use leave-one-out so train will be all but image i, val will be image i
    print('validation using image_{:02d}.jpg'.format(i+1))
    train_selection = image_index != float(i)
    fold_x = xs[train_selection].numpy()
    fold_y = (ys[train_selection] > 0).long().numpy()
    val_x = xs[~train_selection].numpy()
    val_y = (ys[~train_selection] > 0).long().numpy()

    plt.figure()
    for j, c in enumerate(cs):
        print("training logistic regression with C={:.2e}".format(c))
        clf = LogisticRegression(random_state=0, C=c, max_iter=10000).fit(fold_x, fold_y)
        output = clf.predict_proba(val_x)
        precision, recall, thresholds = precision_recall_curve(val_y, output[:, 1])
        s = average_precision_score(val_y, output[:, 1])
        scores[i, j] = s
        plt.plot(recall, precision, label='C={:.1e} AP={:.1f}'.format(c, s*100))

    plt.grid()
    plt.xlabel('recall')
    plt.title('image_{:02d}.jpg'.format(i+1))
    plt.ylabel('precision')
    plt.axis([0, 1, 0, 1])
    plt.legend()
    plt.show()
# Out:
# validation using image_01.jpg
# training logisitic regression with C=1.00e-07
# training logisitic regression with C=2.08e-07
# training logisitic regression with C=4.33e-07
# training logisitic regression with C=9.01e-07
# training logisitic regression with C=1.87e-06
# training logisitic regression with C=3.90e-06
# training logisitic regression with C=8.11e-06
# training logisitic regression with C=1.69e-05
# training logisitic regression with C=3.51e-05
# training logisitic regression with C=7.31e-05
# training logisitic regression with C=1.52e-04
# training logisitic regression with C=3.16e-04
# training logisitic regression with C=6.58e-04
# training logisitic regression with C=1.37e-03
# training logisitic regression with C=2.85e-03
# training logisitic regression with C=5.93e-03
# training logisitic regression with C=1.23e-02
# training logisitic regression with C=2.57e-02
# training logisitic regression with C=5.34e-02
# training logisitic regression with C=1.11e-01
# training logisitic regression with C=2.31e-01
# training logisitic regression with C=4.81e-01
# training logisitic regression with C=1.00e+00
# validation using image_02.jpg
# training logisitic regression with C=1.00e-07
# training logisitic regression with C=2.08e-07
# training logisitic regression with C=4.33e-07
# training logisitic regression with C=9.01e-07
# training logisitic regression with C=1.87e-06
# training logisitic regression with C=3.90e-06
# training logisitic regression with C=8.11e-06
# training logisitic regression with C=1.69e-05
# training logisitic regression with C=3.51e-05
# training logisitic regression with C=7.31e-05
# training logisitic regression with C=1.52e-04
# training logisitic regression with C=3.16e-04
# training logisitic regression with C=6.58e-04
# training logisitic regression with C=1.37e-03
# training logisitic regression with C=2.85e-03
# training logisitic regression with C=5.93e-03
# training logisitic regression with C=1.23e-02
# training logisitic regression with C=2.57e-02
# training logisitic regression with C=5.34e-02
# training logisitic regression with C=1.11e-01
# training logisitic regression with C=2.31e-01
# training logisitic regression with C=4.81e-01
# training logisitic regression with C=1.00e+00
# validation using image_03.jpg
# training logisitic regression with C=1.00e-07
# training logisitic regression with C=2.08e-07
# training logisitic regression with C=4.33e-07
# training logisitic regression with C=9.01e-07
# training logisitic regression with C=1.87e-06
# training logisitic regression with C=3.90e-06
# training logisitic regression with C=8.11e-06
# training logisitic regression with C=1.69e-05
# training logisitic regression with C=3.51e-05
# training logisitic regression with C=7.31e-05
# training logisitic regression with C=1.52e-04
# training logisitic regression with C=3.16e-04
# training logisitic regression with C=6.58e-04
# training logisitic regression with C=1.37e-03
# training logisitic regression with C=2.85e-03
# training logisitic regression with C=5.93e-03
# training logisitic regression with C=1.23e-02
# training logisitic regression with C=2.57e-02
# training logisitic regression with C=5.34e-02
# training logisitic regression with C=1.11e-01
# training logisitic regression with C=2.31e-01
# training logisitic regression with C=4.81e-01
# training logisitic regression with C=1.00e+00
# validation using image_04.jpg
# training logisitic regression with C=1.00e-07
# training logisitic regression with C=2.08e-07
# training logisitic regression with C=4.33e-07
# training logisitic regression with C=9.01e-07
# training logisitic regression with C=1.87e-06
# training logisitic regression with C=3.90e-06
# training logisitic regression with C=8.11e-06
# training logisitic regression with C=1.69e-05
# training logisitic regression with C=3.51e-05
# training logisitic regression with C=7.31e-05
# training logisitic regression with C=1.52e-04
# training logisitic regression with C=3.16e-04
# training logisitic regression with C=6.58e-04
# training logisitic regression with C=1.37e-03
# training logisitic regression with C=2.85e-03
# training logisitic regression with C=5.93e-03
# training logisitic regression with C=1.23e-02
# training logisitic regression with C=2.57e-02
# training logisitic regression with C=5.34e-02
# training logisitic regression with C=1.11e-01
# training logisitic regression with C=2.31e-01
# training logisitic regression with C=4.81e-01
# training logisitic regression with C=1.00e+00
# validation using image_05.jpg
# training logisitic regression with C=1.00e-07
# training logisitic regression with C=2.08e-07
# training logisitic regression with C=4.33e-07
# training logisitic regression with C=9.01e-07
# training logisitic regression with C=1.87e-06
# training logisitic regression with C=3.90e-06
# training logisitic regression with C=8.11e-06
# training logisitic regression with C=1.69e-05
# training logisitic regression with C=3.51e-05
# training logisitic regression with C=7.31e-05
# training logisitic regression with C=1.52e-04
# training logisitic regression with C=3.16e-04
# training logisitic regression with C=6.58e-04
# training logisitic regression with C=1.37e-03
# training logisitic regression with C=2.85e-03
# training logisitic regression with C=5.93e-03
# training logisitic regression with C=1.23e-02
# training logisitic regression with C=2.57e-02
# training logisitic regression with C=5.34e-02
# training logisitic regression with C=1.11e-01
# training logisitic regression with C=2.31e-01
# training logisitic regression with C=4.81e-01
# training logisitic regression with C=1.00e+00
# validation using image_06.jpg
# training logisitic regression with C=1.00e-07
# training logisitic regression with C=2.08e-07
# training logisitic regression with C=4.33e-07
# training logisitic regression with C=9.01e-07
# training logisitic regression with C=1.87e-06
# training logisitic regression with C=3.90e-06
# training logisitic regression with C=8.11e-06
# training logisitic regression with C=1.69e-05
# training logisitic regression with C=3.51e-05
# training logisitic regression with C=7.31e-05
# training logisitic regression with C=1.52e-04
# training logisitic regression with C=3.16e-04
# training logisitic regression with C=6.58e-04
# training logisitic regression with C=1.37e-03
# training logisitic regression with C=2.85e-03
# training logisitic regression with C=5.93e-03
# training logisitic regression with C=1.23e-02
# training logisitic regression with C=2.57e-02
# training logisitic regression with C=5.34e-02
# training logisitic regression with C=1.11e-01
# training logisitic regression with C=2.31e-01
# training logisitic regression with C=4.81e-01
# training logisitic regression with C=1.00e+00
# validation using image_07.jpg
# training logisitic regression with C=1.00e-07
# training logisitic regression with C=2.08e-07
# training logisitic regression with C=4.33e-07
# training logisitic regression with C=9.01e-07
# training logisitic regression with C=1.87e-06
# training logisitic regression with C=3.90e-06
# training logisitic regression with C=8.11e-06
# training logisitic regression with C=1.69e-05
# training logisitic regression with C=3.51e-05
# training logisitic regression with C=7.31e-05
# training logisitic regression with C=1.52e-04
# training logisitic regression with C=3.16e-04
# training logisitic regression with C=6.58e-04
# training logisitic regression with C=1.37e-03
# training logisitic regression with C=2.85e-03
# training logisitic regression with C=5.93e-03
# training logisitic regression with C=1.23e-02
# training logisitic regression with C=2.57e-02
# training logisitic regression with C=5.34e-02
# training logisitic regression with C=1.11e-01
# training logisitic regression with C=2.31e-01
# training logisitic regression with C=4.81e-01
# training logisitic regression with C=1.00e+00
# validation using image_08.jpg
# training logisitic regression with C=1.00e-07
# training logisitic regression with C=2.08e-07
# training logisitic regression with C=4.33e-07
# training logisitic regression with C=9.01e-07
# training logisitic regression with C=1.87e-06
# training logisitic regression with C=3.90e-06
# training logisitic regression with C=8.11e-06
# training logisitic regression with C=1.69e-05
# training logisitic regression with C=3.51e-05
# training logisitic regression with C=7.31e-05
# training logisitic regression with C=1.52e-04
# training logisitic regression with C=3.16e-04
# training logisitic regression with C=6.58e-04
# training logisitic regression with C=1.37e-03
# training logisitic regression with C=2.85e-03
# training logisitic regression with C=5.93e-03
# training logisitic regression with C=1.23e-02
# training logisitic regression with C=2.57e-02
# training logisitic regression with C=5.34e-02
# training logisitic regression with C=1.11e-01
# training logisitic regression with C=2.31e-01
# training logisitic regression with C=4.81e-01
# training logisitic regression with C=1.00e+00
# validation using image_09.jpg
# training logisitic regression with C=1.00e-07
# training logisitic regression with C=2.08e-07
# training logisitic regression with C=4.33e-07
# training logisitic regression with C=9.01e-07
# training logisitic regression with C=1.87e-06
# training logisitic regression with C=3.90e-06
# training logisitic regression with C=8.11e-06
# training logisitic regression with C=1.69e-05
# training logisitic regression with C=3.51e-05
# training logisitic regression with C=7.31e-05
# training logisitic regression with C=1.52e-04
# training logisitic regression with C=3.16e-04
# training logisitic regression with C=6.58e-04
# training logisitic regression with C=1.37e-03
# training logisitic regression with C=2.85e-03
# training logisitic regression with C=5.93e-03
# training logisitic regression with C=1.23e-02
# training logisitic regression with C=2.57e-02
# training logisitic regression with C=5.34e-02
# training logisitic regression with C=1.11e-01
# training logisitic regression with C=2.31e-01
# training logisitic regression with C=4.81e-01
# training logisitic regression with C=1.00e+00
# validation using image_10.jpg
# training logisitic regression with C=1.00e-07
# training logisitic regression with C=2.08e-07
# training logisitic regression with C=4.33e-07
# training logisitic regression with C=9.01e-07
# training logisitic regression with C=1.87e-06
# training logisitic regression with C=3.90e-06
# training logisitic regression with C=8.11e-06
# training logisitic regression with C=1.69e-05
# training logisitic regression with C=3.51e-05
# training logisitic regression with C=7.31e-05
# training logisitic regression with C=1.52e-04
# training logisitic regression with C=3.16e-04
# training logisitic regression with C=6.58e-04
# training logisitic regression with C=1.37e-03
# training logisitic regression with C=2.85e-03
# training logisitic regression with C=5.93e-03
# training logisitic regression with C=1.23e-02
# training logisitic regression with C=2.57e-02
# training logisitic regression with C=5.34e-02
# training logisitic regression with C=1.11e-01
# training logisitic regression with C=2.31e-01
# training logisitic regression with C=4.81e-01
# training logisitic regression with C=1.00e+00
# validation using image_11.jpg
# training logisitic regression with C=1.00e-07
# training logisitic regression with C=2.08e-07
# training logisitic regression with C=4.33e-07
# training logisitic regression with C=9.01e-07
# training logisitic regression with C=1.87e-06
# training logisitic regression with C=3.90e-06
# training logisitic regression with C=8.11e-06
# training logisitic regression with C=1.69e-05
# training logisitic regression with C=3.51e-05
# training logisitic regression with C=7.31e-05
# training logisitic regression with C=1.52e-04
# training logisitic regression with C=3.16e-04
# training logisitic regression with C=6.58e-04
# training logisitic regression with C=1.37e-03
# training logisitic regression with C=2.85e-03
# training logisitic regression with C=5.93e-03
# training logisitic regression with C=1.23e-02
# training logisitic regression with C=2.57e-02
# training logisitic regression with C=5.34e-02
# training logisitic regression with C=1.11e-01
# training logisitic regression with C=2.31e-01
# training logisitic regression with C=4.81e-01
# training logisitic regression with C=1.00e+00
# validation using image_12.jpg
# training logisitic regression with C=1.00e-07
# training logisitic regression with C=2.08e-07
# training logisitic regression with C=4.33e-07
# training logisitic regression with C=9.01e-07
# training logisitic regression with C=1.87e-06
# training logisitic regression with C=3.90e-06
# training logisitic regression with C=8.11e-06
# training logisitic regression with C=1.69e-05
# training logisitic regression with C=3.51e-05
# training logisitic regression with C=7.31e-05
# training logisitic regression with C=1.52e-04
# training logisitic regression with C=3.16e-04
# training logisitic regression with C=6.58e-04
# training logisitic regression with C=1.37e-03
# training logisitic regression with C=2.85e-03
# training logisitic regression with C=5.93e-03
# training logisitic regression with C=1.23e-02
# training logisitic regression with C=2.57e-02
# training logisitic regression with C=5.34e-02
# training logisitic regression with C=1.11e-01
# training logisitic regression with C=2.31e-01
# training logisitic regression with C=4.81e-01
# training logisitic regression with C=1.00e+00
# validation using image_13.jpg
# training logisitic regression with C=1.00e-07
# training logisitic regression with C=2.08e-07
# training logisitic regression with C=4.33e-07
# training logisitic regression with C=9.01e-07
# training logisitic regression with C=1.87e-06
# training logisitic regression with C=3.90e-06
# training logisitic regression with C=8.11e-06
# training logisitic regression with C=1.69e-05
# training logisitic regression with C=3.51e-05
# training logisitic regression with C=7.31e-05
# training logisitic regression with C=1.52e-04
# training logisitic regression with C=3.16e-04
# training logisitic regression with C=6.58e-04
# training logisitic regression with C=1.37e-03
# training logisitic regression with C=2.85e-03
# training logisitic regression with C=5.93e-03
# training logisitic regression with C=1.23e-02
# training logisitic regression with C=2.57e-02
# training logisitic regression with C=5.34e-02
# training logisitic regression with C=1.11e-01
# training logisitic regression with C=2.31e-01
# training logisitic regression with C=4.81e-01
# training logisitic regression with C=1.00e+00
# validation using image_14.jpg
# training logisitic regression with C=1.00e-07
# training logisitic regression with C=2.08e-07
# training logisitic regression with C=4.33e-07
# training logisitic regression with C=9.01e-07
# training logisitic regression with C=1.87e-06
# training logisitic regression with C=3.90e-06
# training logisitic regression with C=8.11e-06
# training logisitic regression with C=1.69e-05
# training logisitic regression with C=3.51e-05
# training logisitic regression with C=7.31e-05
# training logisitic regression with C=1.52e-04
# training logisitic regression with C=3.16e-04
# training logisitic regression with C=6.58e-04
# training logisitic regression with C=1.37e-03
# training logisitic regression with C=2.85e-03
# training logisitic regression with C=5.93e-03
# training logisitic regression with C=1.23e-02
# training logisitic regression with C=2.57e-02
# training logisitic regression with C=5.34e-02
# training logisitic regression with C=1.11e-01
# training logisitic regression with C=2.31e-01
# training logisitic regression with C=4.81e-01
# training logisitic regression with C=1.00e+00
# validation using image_15.jpg
# training logisitic regression with C=1.00e-07
# training logisitic regression with C=2.08e-07
# training logisitic regression with C=4.33e-07
# training logisitic regression with C=9.01e-07
# training logisitic regression with C=1.87e-06
# training logisitic regression with C=3.90e-06
# training logisitic regression with C=8.11e-06
# training logisitic regression with C=1.69e-05
# training logisitic regression with C=3.51e-05
# training logisitic regression with C=7.31e-05
# training logisitic regression with C=1.52e-04
# training logisitic regression with C=3.16e-04
# training logisitic regression with C=6.58e-04
# training logisitic regression with C=1.37e-03
# training logisitic regression with C=2.85e-03
# training logisitic regression with C=5.93e-03
# training logisitic regression with C=1.23e-02
# training logisitic regression with C=2.57e-02
# training logisitic regression with C=5.34e-02
# training logisitic regression with C=1.11e-01
# training logisitic regression with C=2.31e-01
# training logisitic regression with C=4.81e-01
# training logisitic regression with C=1.00e+00
# validation using image_16.jpg
# training logisitic regression with C=1.00e-07
# training logisitic regression with C=2.08e-07
# training logisitic regression with C=4.33e-07
# training logisitic regression with C=9.01e-07
# training logisitic regression with C=1.87e-06
# training logisitic regression with C=3.90e-06
# training logisitic regression with C=8.11e-06
# training logisitic regression with C=1.69e-05
# training logisitic regression with C=3.51e-05
# training logisitic regression with C=7.31e-05
# training logisitic regression with C=1.52e-04
# training logisitic regression with C=3.16e-04
# training logisitic regression with C=6.58e-04
# training logisitic regression with C=1.37e-03
# training logisitic regression with C=2.85e-03
# training logisitic regression with C=5.93e-03
# training logisitic regression with C=1.23e-02
# training logisitic regression with C=2.57e-02
# training logisitic regression with C=5.34e-02
# training logisitic regression with C=1.11e-01
# training logisitic regression with C=2.31e-01
# training logisitic regression with C=4.81e-01
# training logisitic regression with C=1.00e+00
# validation using image_17.jpg
# training logisitic regression with C=1.00e-07
# training logisitic regression with C=2.08e-07
# training logisitic regression with C=4.33e-07
# training logisitic regression with C=9.01e-07
# training logisitic regression with C=1.87e-06
# training logisitic regression with C=3.90e-06
# training logisitic regression with C=8.11e-06
# training logisitic regression with C=1.69e-05
# training logisitic regression with C=3.51e-05
# training logisitic regression with C=7.31e-05
# training logisitic regression with C=1.52e-04
# training logisitic regression with C=3.16e-04
# training logisitic regression with C=6.58e-04
# training logisitic regression with C=1.37e-03
# training logisitic regression with C=2.85e-03
# training logisitic regression with C=5.93e-03
# training logisitic regression with C=1.23e-02
# training logisitic regression with C=2.57e-02
# training logisitic regression with C=5.34e-02
# training logisitic regression with C=1.11e-01
# training logisitic regression with C=2.31e-01
# training logisitic regression with C=4.81e-01
# training logisitic regression with C=1.00e+00
# validation using image_18.jpg
# training logisitic regression with C=1.00e-07
# training logisitic regression with C=2.08e-07
# training logisitic regression with C=4.33e-07
# training logisitic regression with C=9.01e-07
# training logisitic regression with C=1.87e-06
# training logisitic regression with C=3.90e-06
# training logisitic regression with C=8.11e-06
# training logisitic regression with C=1.69e-05
# training logisitic regression with C=3.51e-05
# training logisitic regression with C=7.31e-05
# training logisitic regression with C=1.52e-04
# training logisitic regression with C=3.16e-04
# training logisitic regression with C=6.58e-04
# training logisitic regression with C=1.37e-03
# training logisitic regression with C=2.85e-03
# training logisitic regression with C=5.93e-03
# training logisitic regression with C=1.23e-02
# training logisitic regression with C=2.57e-02
# training logisitic regression with C=5.34e-02
# training logisitic regression with C=1.11e-01
# training logisitic regression with C=2.31e-01
# training logisitic regression with C=4.81e-01
# training logisitic regression with C=1.00e+00
# validation using image_19.jpg
# training logisitic regression with C=1.00e-07
# training logisitic regression with C=2.08e-07
# training logisitic regression with C=4.33e-07
# training logisitic regression with C=9.01e-07
# training logisitic regression with C=1.87e-06
# training logisitic regression with C=3.90e-06
# training logisitic regression with C=8.11e-06
# training logisitic regression with C=1.69e-05
# training logisitic regression with C=3.51e-05
# training logisitic regression with C=7.31e-05
# training logisitic regression with C=1.52e-04
# training logisitic regression with C=3.16e-04
# training logisitic regression with C=6.58e-04
# training logisitic regression with C=1.37e-03
# training logisitic regression with C=2.85e-03
# training logisitic regression with C=5.93e-03
# training logisitic regression with C=1.23e-02
# training logisitic regression with C=2.57e-02
# training logisitic regression with C=5.34e-02
# training logisitic regression with C=1.11e-01
# training logisitic regression with C=2.31e-01
# training logisitic regression with C=4.81e-01
# training logisitic regression with C=1.00e+00
# validation using image_20.jpg
# training logisitic regression with C=1.00e-07
# training logisitic regression with C=2.08e-07
# training logisitic regression with C=4.33e-07
# training logisitic regression with C=9.01e-07
# training logisitic regression with C=1.87e-06
# training logisitic regression with C=3.90e-06
# training logisitic regression with C=8.11e-06
# training logisitic regression with C=1.69e-05
# training logisitic regression with C=3.51e-05
# training logisitic regression with C=7.31e-05
# training logisitic regression with C=1.52e-04
# training logisitic regression with C=3.16e-04
# training logisitic regression with C=6.58e-04
# training logisitic regression with C=1.37e-03
# training logisitic regression with C=2.85e-03
# training logisitic regression with C=5.93e-03
# training logisitic regression with C=1.23e-02
# training logisitic regression with C=2.57e-02
# training logisitic regression with C=5.34e-02
# training logisitic regression with C=1.11e-01
# training logisitic regression with C=2.31e-01
# training logisitic regression with C=4.81e-01
# training logisitic regression with C=1.00e+00
# validation using image_21.jpg
# training logisitic regression with C=1.00e-07
# training logisitic regression with C=2.08e-07
# training logisitic regression with C=4.33e-07
# training logisitic regression with C=9.01e-07
# training logisitic regression with C=1.87e-06
# training logisitic regression with C=3.90e-06
# training logisitic regression with C=8.11e-06
# training logisitic regression with C=1.69e-05
# training logisitic regression with C=3.51e-05
# training logisitic regression with C=7.31e-05
# training logisitic regression with C=1.52e-04
# training logisitic regression with C=3.16e-04
# training logisitic regression with C=6.58e-04
# training logisitic regression with C=1.37e-03
# training logisitic regression with C=2.85e-03
# training logisitic regression with C=5.93e-03
# training logisitic regression with C=1.23e-02
# training logisitic regression with C=2.57e-02
# training logisitic regression with C=5.34e-02
# training logisitic regression with C=1.11e-01
# training logisitic regression with C=2.31e-01
# training logisitic regression with C=4.81e-01
# training logisitic regression with C=1.00e+00
# validation using image_22.jpg
# training logisitic regression with C=1.00e-07
# training logisitic regression with C=2.08e-07
# training logisitic regression with C=4.33e-07
# training logisitic regression with C=9.01e-07
# training logisitic regression with C=1.87e-06
# training logisitic regression with C=3.90e-06
# training logisitic regression with C=8.11e-06
# training logisitic regression with C=1.69e-05
# training logisitic regression with C=3.51e-05
# training logisitic regression with C=7.31e-05
# training logisitic regression with C=1.52e-04
# training logisitic regression with C=3.16e-04
# training logisitic regression with C=6.58e-04
# training logisitic regression with C=1.37e-03
# training logisitic regression with C=2.85e-03
# training logisitic regression with C=5.93e-03
# training logisitic regression with C=1.23e-02
# training logisitic regression with C=2.57e-02
# training logisitic regression with C=5.34e-02
# training logisitic regression with C=1.11e-01
# training logisitic regression with C=2.31e-01
# training logisitic regression with C=4.81e-01
# training logisitic regression with C=1.00e+00
# validation using image_23.jpg
# training logisitic regression with C=1.00e-07
# training logisitic regression with C=2.08e-07
# training logisitic regression with C=4.33e-07
# training logisitic regression with C=9.01e-07
# training logisitic regression with C=1.87e-06
# training logisitic regression with C=3.90e-06
# training logisitic regression with C=8.11e-06
# training logisitic regression with C=1.69e-05
# training logisitic regression with C=3.51e-05
# training logisitic regression with C=7.31e-05
# training logisitic regression with C=1.52e-04
# training logisitic regression with C=3.16e-04
# training logisitic regression with C=6.58e-04
# training logisitic regression with C=1.37e-03
# training logisitic regression with C=2.85e-03
# training logisitic regression with C=5.93e-03
# training logisitic regression with C=1.23e-02
# training logisitic regression with C=2.57e-02
# training logisitic regression with C=5.34e-02
# training logisitic regression with C=1.11e-01
# training logisitic regression with C=2.31e-01
# training logisitic regression with C=4.81e-01
# training logisitic regression with C=1.00e+00
# validation using image_24.jpg
# training logisitic regression with C=1.00e-07
# training logisitic regression with C=2.08e-07
# training logisitic regression with C=4.33e-07
# training logisitic regression with C=9.01e-07
# training logisitic regression with C=1.87e-06
# training logisitic regression with C=3.90e-06
# training logisitic regression with C=8.11e-06
# training logisitic regression with C=1.69e-05
# training logisitic regression with C=3.51e-05
# training logisitic regression with C=7.31e-05
# training logisitic regression with C=1.52e-04
# training logisitic regression with C=3.16e-04
# training logisitic regression with C=6.58e-04
# training logisitic regression with C=1.37e-03
# training logisitic regression with C=2.85e-03
# training logisitic regression with C=5.93e-03
# training logisitic regression with C=1.23e-02
# training logisitic regression with C=2.57e-02
# training logisitic regression with C=5.34e-02
# training logisitic regression with C=1.11e-01
# training logisitic regression with C=2.31e-01
# training logisitic regression with C=4.81e-01
# training logisitic regression with C=1.00e+00

# %%
plt.figure(figsize=(3, 2), dpi=300)
plt.rcParams.update({
    "xtick.labelsize": 2,
    "ytick.labelsize": 2,
    "axes.labelsize": 2,
})
plt.plot(scores.mean(axis=0))
plt.xticks(np.arange(len(cs)), ["{:.0e}".format(c) for c in cs])
plt.xlabel('data fit C')
plt.ylabel('average AP')
plt.grid()
plt.show()

# %%
#Retraining with the optimal regularization
#Given the above, we seem to have a winner: C=0.053 (take 0.05). Let's now train a model using this optimal data-fit value.
clf = LogisticRegression(random_state=0, C=0.05, max_iter=100000, verbose=2).fit(xs.numpy(), (ys > 0).long().numpy())
# Out:
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.0s finished

# %%
test_image_dir = DPATH+"/test-images/"
test_label_dir = DPATH+"/test-labels/"

#test_image2 = DPATH+"/test-images/551.png" 
# 535, 537, 539, 551, 553
#def prepare_answer(tst_img: Image):
tst_img = DPATH+"/test-images/553.png"
test_image = Image.open(tst_img).convert("RGB")
test_image_resized = resize_transform(test_image)
test_image_normalized = TF.normalize(test_image_resized, mean=IMAGENET_MEAN, std=IMAGENET_STD)
with torch.inference_mode():
    with torch.autocast(device_type='cuda', dtype=torch.float32):
        feats = model.get_intermediate_layers(test_image_normalized.unsqueeze(0).cuda(), n=range(n_layers), reshape=True, norm=True)
        x = feats[-1].squeeze().detach().cpu()
        dim = x.shape[0]
        x = x.view(dim, -1).permute(1, 0)

h_patches, w_patches = [int(d / PATCH_SIZE) for d in test_image_resized.shape[1:]]

fg_score = clf.predict_proba(x)[:, 1].reshape(h_patches, w_patches)
fg_score_mf = torch.from_numpy(signal.medfilt2d(fg_score, kernel_size=3))
#fg_score_mf_resized = resize_transform(fg_score_mf, 256, 16)
#plt.figure(figsize=(9, 3), dpi=300)
#plt.subplot(1, 3, 1)
#plt.axis('off')
#plt.imshow(test_image_resized.permute(1, 2, 0))
#plt.title('input image')
#plt.subplot(1, 3, 2)
#plt.axis('off')
#plt.imshow(fg_score,cmap='gray')
#plt.title('foreground score')
#plt.subplot(1, 3, 3)

plt.figure(figsize=(4.36, 4.36), dpi=72)
plt.axis('off')
plt.imshow(fg_score_mf,cmap='gray')
plt.savefig("/home/levandov/553.png", bbox_inches='tight')
plt.title('fg + median filter')
plt.show()

#for member in sorted(glob.glob(train_images_dir+"*.png")):
#  prepare_answer(member)
# Out:
# 535.png
# 537.png
# 539.png
# 551.png
# 553.png
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 15
#      13 tst_img = DPATH+"/test-images/553.png"
#      14 test_image = Image.open(tst_img).convert("RGB")
# ---> 15 test_image_resized = resize_transform(test_image)
#      16 test_image_normalized = TF.normalize(test_image_resized, mean=IMAGENET_MEAN, std=IMAGENET_STD)
#      17 with torch.inference_mode():
#
# NameError: name 'resize_transform' is not defined

# %%
#Saving the Model for Future Use
save_root = '.'
model_path = os.path.join(save_root, "fg_classifier1.pkl")
with open(model_path, "wb") as f:
  pickle.dump(clf, f)
